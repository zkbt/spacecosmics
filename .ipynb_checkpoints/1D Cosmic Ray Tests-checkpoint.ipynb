# %% [markdown]
# # 1D Cosmic Ray Tests
#
# This notebook shows 1D tests of different cosmic ray mitigation techniques. It creates 1D timeseries, and then bins then according to different techniques. For these tests, we care about a couple of items:
# + How much extra noise to we introduce into binned light curves, just by using an algorithm that's throwing out some of the data?
# + How well does the algorithm eliminate or reduce cosmic ray hits?
# To try to capture both of these points, we make plots showing the achieved standard deviation of the binned data for each different method, as a function of the ratio of the cosmic ray strength to the original binned noise. Most methods (except a straight `Mean`, of course) do a pretty good job of eliminating cosmic rays, but some with long timescale associated with them can fail to perfect zap every cosmic -- these show up as trends of increasing noise with increasing amplitude of cosmic ray strength.
#
# (Note that while we talk about a "cosmic ray strength" in these simple tests, it's probably better to think of this in terms of brighter or fainter stars. Cosmic ray hits are about the same no matter what, but they would appear "weaker" for a bright star where they are a fractionally small ratio of the total flux and "stronger" for a faint star where they are a larger fraction of the total flux.)

# %%
from comparemethods1D import *
# %matplotlib inline

# %% [markdown]
# This `compare` function in `comparemethods1D` includes some cosmic ray mitigation methods for comparisons, but could certainly be modified to explore others.

# %%
compare(nexposures=1324, # how many binned exposures? (e.g. 1324 FFIs in one sector)
        nsubexposures=900, # how many sub-exposures in each exposure (900 two-seconds in one 30 minute)
        niterations=25, # how many times should we do the test? (more gets prettier plots)
        remake=False) # if the data for this already exist, should we remake anyway?
# Out:
# working on mean
#    1 strategies to go!
# testing Mean, with filename of comparingcosmics/Mean/crdemo_filterMean_n5
# trying to load file from  comparingcosmics/Mean/crdemo_filterMean_n5_25iterations_900subexposures.npy
#   iteration #0/25
# /Users/zkbt/anaconda3/envs/mosasaurus/lib/python3.6/site-packages/matplotlib/axes/_base.py:2966: UserWarning: Attempted to set non-positive xlimits for log-scale axis; invalid limits will be ignored.
#   'Attempted to set non-positive xlimits for log-scale axis; '
# saved plot to comparingcosmics/Mean/crdemo_filterMean_n5_cr0p0_1324exposures.pdf
#    1324 exposures, 900 subexposures, cosmic rays 0.0X noise
# saved plot to comparingcosmics/Mean/crdemo_filterMean_n5_cr0p5_1324exposures.pdf
#    1324 exposures, 900 subexposures, cosmic rays 0.5X noise
# saved plot to comparingcosmics/Mean/crdemo_filterMean_n5_cr1p0_1324exposures.pdf
#    1324 exposures, 900 subexposures, cosmic rays 1.0X noise
# saved plot to comparingcosmics/Mean/crdemo_filterMean_n5_cr1p5_1324exposures.pdf
#    1324 exposures, 900 subexposures, cosmic rays 1.5X noise
# saved plot to comparingcosmics/Mean/crdemo_filterMean_n5_cr2p0_1324exposures.pdf
#    1324 exposures, 900 subexposures, cosmic rays 2.0X noise
# saved plot to comparingcosmics/Mean/crdemo_filterMean_n5_cr2p5_1324exposures.pdf
#    1324 exposures, 900 subexposures, cosmic rays 2.5X noise
# saved plot to comparingcosmics/Mean/crdemo_filterMean_n5_cr3p0_1324exposures.pdf
#    1324 exposures, 900 subexposures, cosmic rays 3.0X noise
# saved plot to comparingcosmics/Mean/crdemo_filterMean_n5_cr3p5_1324exposures.pdf
#    1324 exposures, 900 subexposures, cosmic rays 3.5X noise
# saved plot to comparingcosmics/Mean/crdemo_filterMean_n5_cr4p0_1324exposures.pdf
#    1324 exposures, 900 subexposures, cosmic rays 4.0X noise
# saved plot to comparingcosmics/Mean/crdemo_filterMean_n5_cr4p5_1324exposures.pdf
#    1324 exposures, 900 subexposures, cosmic rays 4.5X noise
#   iteration #1/25
#    1324 exposures, 900 subexposures, cosmic rays 0.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 0.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 1.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 1.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 2.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 2.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 3.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 3.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 4.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 4.5X noise
#   iteration #2/25
#    1324 exposures, 900 subexposures, cosmic rays 0.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 0.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 1.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 1.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 2.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 2.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 3.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 3.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 4.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 4.5X noise
#   iteration #3/25
#    1324 exposures, 900 subexposures, cosmic rays 0.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 0.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 1.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 1.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 2.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 2.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 3.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 3.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 4.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 4.5X noise
#   iteration #4/25
#    1324 exposures, 900 subexposures, cosmic rays 0.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 0.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 1.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 1.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 2.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 2.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 3.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 3.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 4.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 4.5X noise
#   iteration #5/25
#    1324 exposures, 900 subexposures, cosmic rays 0.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 0.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 1.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 1.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 2.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 2.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 3.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 3.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 4.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 4.5X noise
#   iteration #6/25
#    1324 exposures, 900 subexposures, cosmic rays 0.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 0.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 1.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 1.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 2.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 2.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 3.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 3.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 4.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 4.5X noise
#   iteration #7/25
#    1324 exposures, 900 subexposures, cosmic rays 0.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 0.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 1.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 1.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 2.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 2.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 3.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 3.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 4.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 4.5X noise
#   iteration #8/25
#    1324 exposures, 900 subexposures, cosmic rays 0.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 0.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 1.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 1.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 2.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 2.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 3.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 3.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 4.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 4.5X noise
#   iteration #9/25
#    1324 exposures, 900 subexposures, cosmic rays 0.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 0.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 1.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 1.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 2.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 2.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 3.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 3.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 4.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 4.5X noise
#   iteration #10/25
#    1324 exposures, 900 subexposures, cosmic rays 0.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 0.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 1.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 1.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 2.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 2.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 3.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 3.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 4.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 4.5X noise
#   iteration #11/25
#    1324 exposures, 900 subexposures, cosmic rays 0.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 0.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 1.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 1.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 2.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 2.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 3.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 3.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 4.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 4.5X noise
#   iteration #12/25
#    1324 exposures, 900 subexposures, cosmic rays 0.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 0.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 1.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 1.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 2.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 2.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 3.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 3.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 4.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 4.5X noise
#   iteration #13/25
#    1324 exposures, 900 subexposures, cosmic rays 0.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 0.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 1.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 1.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 2.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 2.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 3.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 3.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 4.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 4.5X noise
#   iteration #14/25
#    1324 exposures, 900 subexposures, cosmic rays 0.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 0.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 1.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 1.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 2.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 2.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 3.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 3.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 4.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 4.5X noise
#   iteration #15/25
#    1324 exposures, 900 subexposures, cosmic rays 0.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 0.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 1.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 1.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 2.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 2.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 3.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 3.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 4.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 4.5X noise
#   iteration #16/25
#    1324 exposures, 900 subexposures, cosmic rays 0.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 0.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 1.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 1.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 2.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 2.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 3.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 3.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 4.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 4.5X noise
#   iteration #17/25
#    1324 exposures, 900 subexposures, cosmic rays 0.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 0.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 1.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 1.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 2.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 2.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 3.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 3.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 4.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 4.5X noise
#   iteration #18/25
#    1324 exposures, 900 subexposures, cosmic rays 0.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 0.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 1.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 1.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 2.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 2.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 3.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 3.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 4.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 4.5X noise
#   iteration #19/25
#    1324 exposures, 900 subexposures, cosmic rays 0.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 0.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 1.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 1.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 2.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 2.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 3.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 3.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 4.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 4.5X noise
#   iteration #20/25
#    1324 exposures, 900 subexposures, cosmic rays 0.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 0.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 1.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 1.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 2.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 2.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 3.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 3.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 4.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 4.5X noise
#   iteration #21/25
#    1324 exposures, 900 subexposures, cosmic rays 0.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 0.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 1.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 1.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 2.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 2.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 3.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 3.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 4.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 4.5X noise
#   iteration #22/25
#    1324 exposures, 900 subexposures, cosmic rays 0.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 0.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 1.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 1.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 2.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 2.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 3.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 3.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 4.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 4.5X noise
#   iteration #23/25
#    1324 exposures, 900 subexposures, cosmic rays 0.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 0.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 1.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 1.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 2.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 2.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 3.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 3.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 4.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 4.5X noise
#   iteration #24/25
#    1324 exposures, 900 subexposures, cosmic rays 0.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 0.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 1.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 1.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 2.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 2.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 3.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 3.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 4.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 4.5X noise
#    saved results to  comparingcosmics/Mean/crdemo_filterMean_n5_25iterations_900subexposures.npy
# working on median
#    5 strategies to go!
# testing Median of 6, with filename of comparingcosmics/Medianof6/crdemo_filterMedianof6_n6
# trying to load file from  comparingcosmics/Medianof6/crdemo_filterMedianof6_n6_25iterations_900subexposures.npy
#   iteration #0/25
# saved plot to comparingcosmics/Medianof6/crdemo_filterMedianof6_n6_cr0p0_1324exposures.pdf
#    1324 exposures, 900 subexposures, cosmic rays 0.0X noise
# saved plot to comparingcosmics/Medianof6/crdemo_filterMedianof6_n6_cr0p5_1324exposures.pdf
#    1324 exposures, 900 subexposures, cosmic rays 0.5X noise
# saved plot to comparingcosmics/Medianof6/crdemo_filterMedianof6_n6_cr1p0_1324exposures.pdf
#    1324 exposures, 900 subexposures, cosmic rays 1.0X noise
# saved plot to comparingcosmics/Medianof6/crdemo_filterMedianof6_n6_cr1p5_1324exposures.pdf
#    1324 exposures, 900 subexposures, cosmic rays 1.5X noise
# saved plot to comparingcosmics/Medianof6/crdemo_filterMedianof6_n6_cr2p0_1324exposures.pdf
#    1324 exposures, 900 subexposures, cosmic rays 2.0X noise
# saved plot to comparingcosmics/Medianof6/crdemo_filterMedianof6_n6_cr2p5_1324exposures.pdf
#    1324 exposures, 900 subexposures, cosmic rays 2.5X noise
# saved plot to comparingcosmics/Medianof6/crdemo_filterMedianof6_n6_cr3p0_1324exposures.pdf
#    1324 exposures, 900 subexposures, cosmic rays 3.0X noise
# saved plot to comparingcosmics/Medianof6/crdemo_filterMedianof6_n6_cr3p5_1324exposures.pdf
#    1324 exposures, 900 subexposures, cosmic rays 3.5X noise
# saved plot to comparingcosmics/Medianof6/crdemo_filterMedianof6_n6_cr4p0_1324exposures.pdf
#    1324 exposures, 900 subexposures, cosmic rays 4.0X noise
# saved plot to comparingcosmics/Medianof6/crdemo_filterMedianof6_n6_cr4p5_1324exposures.pdf
#    1324 exposures, 900 subexposures, cosmic rays 4.5X noise
#   iteration #1/25
#    1324 exposures, 900 subexposures, cosmic rays 0.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 0.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 1.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 1.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 2.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 2.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 3.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 3.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 4.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 4.5X noise
#   iteration #2/25
#    1324 exposures, 900 subexposures, cosmic rays 0.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 0.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 1.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 1.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 2.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 2.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 3.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 3.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 4.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 4.5X noise
#   iteration #3/25
#    1324 exposures, 900 subexposures, cosmic rays 0.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 0.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 1.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 1.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 2.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 2.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 3.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 3.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 4.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 4.5X noise
#   iteration #4/25
#    1324 exposures, 900 subexposures, cosmic rays 0.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 0.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 1.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 1.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 2.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 2.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 3.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 3.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 4.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 4.5X noise
#   iteration #5/25
#    1324 exposures, 900 subexposures, cosmic rays 0.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 0.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 1.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 1.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 2.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 2.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 3.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 3.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 4.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 4.5X noise
#   iteration #6/25
#    1324 exposures, 900 subexposures, cosmic rays 0.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 0.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 1.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 1.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 2.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 2.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 3.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 3.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 4.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 4.5X noise
#   iteration #7/25
#    1324 exposures, 900 subexposures, cosmic rays 0.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 0.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 1.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 1.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 2.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 2.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 3.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 3.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 4.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 4.5X noise
#   iteration #8/25
#    1324 exposures, 900 subexposures, cosmic rays 0.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 0.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 1.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 1.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 2.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 2.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 3.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 3.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 4.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 4.5X noise
#   iteration #9/25
#    1324 exposures, 900 subexposures, cosmic rays 0.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 0.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 1.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 1.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 2.0X noise
#    1324 exposures, 900 subexposures, cosmic rays 2.5X noise
#    1324 exposures, 900 subexposures, cosmic rays 3.0X noise

# %%
from IPython.display import IFrame
IFrame("comparingcosmics/cosmicrayrejectioncomparisons_25iterations_900subexposures_everything.pdf",
       width=800, height=500)
